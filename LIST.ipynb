# %% [markdown]
# <a href="https://colab.research.google.com/github/sahasya-cpu/SD_sahasya-0120/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums= [1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
type(nums)
# Out:
# list

# %%
l=[1,"sahasya",]

# %%
l
# Out:
# [1, 'sahasya']

# %%
l=[1,1.1,"sahasya",True]

# %%
print(l [::2])
# Out:
# [1, 'sahasya']

# %%
l[::-1]
# Out:
# [True, 'sahasya', 1.1, 1]

# %%
l=[1,345,34,'sudh',True,(5+7j),345.456]
l[-1::-6]
# Out:
# [345.456, 1]

# %%
l.append("e")

# %%
l.remove("e")

# %%
l
# Out:
# [1, 345, 34, 'sudh', True, (5+7j), 345.456]

# %%
s="a quick brown fox jumped over the lazy dog"

# %%
l.append(s)

# %%
l
# Out:
# [1,
#  345,
#  34,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  'a quick brown fox jumped over the lazy dog']

# %%
l.pop()
list(s)
# Out:
# ['a',
#  ' ',
#  'q',
#  'u',
#  'i',
#  'c',
#  'k',
#  ' ',
#  'b',
#  'r',
#  'o',
#  'w',
#  'n',
#  ' ',
#  'f',
#  'o',
#  'x',
#  ' ',
#  'j',
#  'u',
#  'm',
#  'p',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'v',
#  'e',
#  'r',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'l',
#  'a',
#  'z',
#  'y',
#  ' ',
#  'd',
#  'o',
#  'g']

# %%
list(s)+l
# Out:
# ['a',
#  ' ',
#  'q',
#  'u',
#  'i',
#  'c',
#  'k',
#  ' ',
#  'b',
#  'r',
#  'o',
#  'w',
#  'n',
#  ' ',
#  'f',
#  'o',
#  'x',
#  ' ',
#  'j',
#  'u',
#  'm',
#  'p',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'v',
#  'e',
#  'r',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'l',
#  'a',
#  'z',
#  'y',
#  ' ',
#  'd',
#  'o',
#  'g',
#  1,
#  345,
#  34,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l1=[]

# %%
l1.append(143
          )

# %%
l1.pop()
# Out:
# 143

# %%
l=[1, 345, 34, 'sudh', True, (5+7j), 345.456]

# %%
l[3][:2:]
# Out:
# 'su'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l.insert(2,"mayur
")
# Out:
#   File "/tmp/ipykernel_660/86806539.py", line 1
#     l.insert(2,"mayur
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
l.insert(2,"mayur")

# %%
l.remove("mayur")

# %%
l
# Out:
# [1, 345, 34, 'sudh', True, (5+7j), 345.456]

# %%
x=input("enter kar bhai")
# Out:
# enter kar bhaibhak

# %%
name = input("enter your name:-")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_660/1407348486.py", line 1, in <cell line: 0>
#     name = input("enter your name:-")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 1177, in raw_input
#     return self._input_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 1219, in _input_request
#     raise KeyboardInterrupt("Interrupted by user") from None
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
name = input("enter your name:-")
age = int(input("enter your age"))
print ("Hi ",name)
print("Your age is ", age)
# Out:
# enter your name:-SAHASYA
# enter your age19
# Hi  SAHASYA
# Your age is  19

# %%
x= (1,2,3)

# %%
y=list(x)

# %%
y
# Out:
# [1, 2, 3]

# %%
l=[1,345,45,"sudh",True,5+7j,345.456]

# %%
l[::]
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l[4]
# Out:
# True

# %%
l.insert(2,"sup")

# %%
l
# Out:
# [1, 345, 'sup', 45, 'sudh', True, (5+7j), 345.456]

# %%
l.pop(2)
# Out:
# 'sup'

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
d={}

# %%
d1={"key" : "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
type(d1)
# Out:
# dict

# %%
d2={"name": "sahasya",
    "email": "sahasya@gmail.com",
    "number": 6387390083}

# %%
d2
# Out:
# {'name': 'sahasya', 'email': 'sahasya@gmail.com', 'number': 6387390083}
